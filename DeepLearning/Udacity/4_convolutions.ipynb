# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
import os, pickle
import numpy as np
import tensorflow as tf

# %%
data_root = './dataset/'
pickle_file = os.path.join(data_root, 'noMNIST_sanit.pickle')

# %%
with open(pickle_file, 'rb') as f:
    data = pickle.load(f, encoding='bytes')
    print('Data dict\'s key:', data.keys())
    _train_dataset = data['train_dataset']
    _train_labels = data['train_labels']
    _valid_dataset = data['valid_dataset']
    _valid_labels = data['valid_labels']
    _test_dataset = data['test_dataset']
    _test_labels = data['test_labels']
    del data
    print('Train set', _train_dataset.shape, 'Labels:', _train_labels.shape)
    print('Valid set', _valid_dataset.shape, 'Labels:', _valid_labels.shape)
    print('Test set', _test_dataset.shape, 'Labels:', _test_labels.shape)
# Out:
# Data dict's key: dict_keys(['train_dataset', 'train_labels', 'valid_dataset', 'valid_labels', 'test_dataset', 'test_labels'])
# Train set (200000, 28, 28) Labels: (200000,)
# Valid set (8927, 28, 28) Labels: (8927,)
# Test set (8736, 28, 28) Labels: (8736,)

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale. 

def reformat_with_channels(dataset, labels):
    dataset = dataset.reshape((-1, image_size, image_size, num_channels)).astype(np.float32)
    labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
    return dataset, labels

train_dataset, train_labels = reformat_with_channels(_train_dataset, _train_labels)
valid_dataset, valid_labels = reformat_with_channels(_valid_dataset, _valid_labels)
test_dataset, test_labels = reformat_with_channels(_test_dataset, _test_labels)

print('Train set', train_dataset.shape, 'Labels:',train_labels.shape)
print('Valid set', valid_dataset.shape, 'Labels:',valid_labels.shape)
print('Test set', test_dataset.shape, 'Labels:',test_labels.shape)
#print('[data]:\n', test_dataset[:1], '\n', '[label]:\n', test_labels[:1])
# Out:
# Train set (200000, 28, 28, 1) Labels: (200000, 10)
# Valid set (8927, 28, 28, 1) Labels: (8927, 10)
# Test set (8736, 28, 28, 1) Labels: (8736, 10)

# %%
def accuracy(predictions, labels):
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():
    # Input data.
    # tf_train_dataset: (16, 28, 28, 1)
    tf_train_dataset = tf.placeholder(dtype=tf.float32,
                                     shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(dtype=tf.float32,
                                    shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    
    # kernel: [5, 5, 1, 16], stride=2, padding=same
    # lay1_weights: [16, 14, 14, 16]
    lay1_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, num_channels, depth], stddev=0.1))
    lay1_biases = tf.Variable(tf.zeros([lay1_weights.shape[-1]]))
    # conv kernel = [k_width, k_height, channel, k_num]
    # The channel size must be equal to the input's channel.
    
    # kernel: [5, 5, 16, 16], stride=2, padding=same
    # lay2_weights: [16, 7, 7, 16]
    lay2_weights = tf.Variable(
        tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    lay2_biases = tf.Variable(tf.zeros(depth))
    
    # Fully connect: [16, 7*7*16] * [7*7*16, num_hidden]
    # Output: [16, num_hidden]
    lay3_weights = tf.Variable(
        tf.truncated_normal([image_size // 4 * image_size // 4 * depth, num_hidden]))
    lay3_biases = tf.Variable(tf.zeros(num_hidden))
    
    # [16, num_hidden] * [num_hidden, num_labels]
    # Output: [16, num_labels]
    lay4_weights = tf.Variable(
        tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    lay4_biases = tf.Variable(tf.constant(1., shape=[num_labels]))
    
    def model(data):
        # The first convolutional layer.
        conv = tf.nn.conv2d(input=data, 
                            filter=lay1_weights,
                            strides=[1,2,2,1],
                            padding='SAME')
        # Activation Function: Relu.
        hidden = tf.nn.relu(conv + lay1_biases)
        
        
        # The second convolutional layer.
        conv = tf.nn.conv2d(input=hidden,
                           filter=lay2_weights,
                           strides=[1,2,2,1],
                           padding='SAME')
        hidden = tf.nn.relu(conv + lay2_biases)
        
        shape = hidden.get_shape().as_list()
        reshape = tf.reshape(tensor=hidden,
                            shape=[shape[0], shape[1]*shape[2]*shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, lay3_weights) + lay3_biases)
        return tf.matmul(hidden, lay4_weights) + lay4_biases
    
    # Training computation
    _logits = model(tf_train_dataset)
    _loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits_v2(labels=tf_train_labels,
                                                logits=_logits))
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(_loss)
    
    # Predictions for the training.
    train_prediction = tf.nn.softmax(_logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
steps = 100000
step_val = []
accuracy_val = []

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('[Tensorflow]: Initialized!')
    for step in range(steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        
        # Generate minibatch.
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        
        # Feed it.
        feed_dict = {tf_train_dataset: batch_data, 
                     tf_train_labels: batch_labels}
        
        _, loss, predictions = session.run([optimizer, 
                                                _loss, 
                                                train_prediction], feed_dict=feed_dict)
            
        if ((step+1) % 500 == 0):
            print('Minibatch step: %d, loss: %4.5f, acc: %.1f%%, valid_acc: %.1f%%.'
                  % ((step+1), loss,
                     accuracy(predictions, batch_labels), 
                     accuracy(valid_prediction.eval(), valid_labels)))
            step_val.append(step+1)
            accuracy_val.append(loss)
    print('Test Accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# [Tensorflow]: Initialized!
# Minibatch step: 500, loss: 0.42494, acc: 87.5%, valid_acc: 74.6%.
# Minibatch step: 1000, loss: 0.97117, acc: 75.0%, valid_acc: 78.6%.
# Minibatch step: 1500, loss: 1.11262, acc: 75.0%, valid_acc: 78.6%.
# Minibatch step: 2000, loss: 0.06846, acc: 100.0%, valid_acc: 80.7%.
# Minibatch step: 2500, loss: 1.25020, acc: 75.0%, valid_acc: 80.4%.
# Minibatch step: 3000, loss: 1.21836, acc: 62.5%, valid_acc: 81.3%.
# Minibatch step: 3500, loss: 0.70489, acc: 81.2%, valid_acc: 81.7%.
# Minibatch step: 4000, loss: 0.89826, acc: 75.0%, valid_acc: 82.2%.
# Minibatch step: 4500, loss: 0.65841, acc: 75.0%, valid_acc: 81.1%.
# Minibatch step: 5000, loss: 0.72821, acc: 75.0%, valid_acc: 81.0%.
# Minibatch step: 5500, loss: 0.25699, acc: 87.5%, valid_acc: 83.3%.
# Minibatch step: 6000, loss: 0.79658, acc: 68.8%, valid_acc: 82.9%.
# Minibatch step: 6500, loss: 0.77314, acc: 81.2%, valid_acc: 82.4%.
# Minibatch step: 7000, loss: 0.76092, acc: 68.8%, valid_acc: 83.1%.
# Minibatch step: 7500, loss: 0.45604, acc: 87.5%, valid_acc: 82.8%.
# Minibatch step: 8000, loss: 0.62406, acc: 81.2%, valid_acc: 83.2%.
# Minibatch step: 8500, loss: 0.40953, acc: 87.5%, valid_acc: 83.2%.
# Minibatch step: 9000, loss: 0.72484, acc: 81.2%, valid_acc: 81.9%.
# Minibatch step: 9500, loss: 0.47697, acc: 87.5%, valid_acc: 83.7%.
# Minibatch step: 10000, loss: 0.58452, acc: 81.2%, valid_acc: 83.4%.
# Minibatch step: 10500, loss: 0.26502, acc: 87.5%, valid_acc: 84.1%.
# Minibatch step: 11000, loss: 0.81496, acc: 68.8%, valid_acc: 83.4%.
# Minibatch step: 11500, loss: 0.19496, acc: 93.8%, valid_acc: 83.6%.
# Minibatch step: 12000, loss: 0.15006, acc: 100.0%, valid_acc: 83.4%.
# Minibatch step: 12500, loss: 0.45083, acc: 87.5%, valid_acc: 83.3%.
# Minibatch step: 13000, loss: 0.98225, acc: 81.2%, valid_acc: 82.6%.
# Minibatch step: 13500, loss: 0.17272, acc: 93.8%, valid_acc: 84.2%.
# Minibatch step: 14000, loss: 0.91134, acc: 68.8%, valid_acc: 84.3%.
# Minibatch step: 14500, loss: 0.24190, acc: 93.8%, valid_acc: 84.5%.
# Minibatch step: 15000, loss: 0.29447, acc: 87.5%, valid_acc: 83.7%.
# Minibatch step: 15500, loss: 0.46637, acc: 81.2%, valid_acc: 84.2%.
# Minibatch step: 16000, loss: 0.46278, acc: 87.5%, valid_acc: 83.9%.
# Minibatch step: 16500, loss: 0.18636, acc: 93.8%, valid_acc: 84.4%.
# Minibatch step: 17000, loss: 0.26466, acc: 93.8%, valid_acc: 82.9%.
# Minibatch step: 17500, loss: 0.60177, acc: 81.2%, valid_acc: 84.4%.
# Minibatch step: 18000, loss: 0.43500, acc: 93.8%, valid_acc: 84.9%.
# Minibatch step: 18500, loss: 0.49870, acc: 81.2%, valid_acc: 84.4%.
# Minibatch step: 19000, loss: 0.15246, acc: 93.8%, valid_acc: 84.1%.
# Minibatch step: 19500, loss: 0.26662, acc: 93.8%, valid_acc: 85.0%.
# Minibatch step: 20000, loss: 1.24764, acc: 75.0%, valid_acc: 83.8%.
# Minibatch step: 20500, loss: 0.45419, acc: 87.5%, valid_acc: 84.1%.
# Minibatch step: 21000, loss: 0.28775, acc: 93.8%, valid_acc: 84.6%.
# Minibatch step: 21500, loss: 0.74333, acc: 81.2%, valid_acc: 84.2%.
# Minibatch step: 22000, loss: 0.39898, acc: 87.5%, valid_acc: 84.1%.
# Minibatch step: 22500, loss: 0.22364, acc: 93.8%, valid_acc: 84.2%.
# Minibatch step: 23000, loss: 0.71248, acc: 68.8%, valid_acc: 84.7%.
# Minibatch step: 23500, loss: 0.76978, acc: 81.2%, valid_acc: 84.6%.
# Minibatch step: 24000, loss: 0.30411, acc: 93.8%, valid_acc: 84.7%.
# Minibatch step: 24500, loss: 0.22865, acc: 93.8%, valid_acc: 84.8%.
# Minibatch step: 25000, loss: 1.49678, acc: 62.5%, valid_acc: 84.9%.
# Minibatch step: 25500, loss: 0.12504, acc: 100.0%, valid_acc: 84.7%.
# Minibatch step: 26000, loss: 0.66414, acc: 87.5%, valid_acc: 85.2%.
# Minibatch step: 26500, loss: 0.52223, acc: 87.5%, valid_acc: 84.8%.
# Minibatch step: 27000, loss: 0.72340, acc: 75.0%, valid_acc: 84.4%.
# Minibatch step: 27500, loss: 0.66442, acc: 81.2%, valid_acc: 84.8%.
# Minibatch step: 28000, loss: 0.32962, acc: 87.5%, valid_acc: 84.9%.
# Minibatch step: 28500, loss: 0.75950, acc: 81.2%, valid_acc: 84.6%.
# Minibatch step: 29000, loss: 0.60057, acc: 81.2%, valid_acc: 84.9%.
# Minibatch step: 29500, loss: 0.94600, acc: 75.0%, valid_acc: 84.9%.
# Minibatch step: 30000, loss: 0.42623, acc: 81.2%, valid_acc: 85.1%.
# Minibatch step: 30500, loss: 0.72678, acc: 81.2%, valid_acc: 85.2%.
# Minibatch step: 31000, loss: 0.88384, acc: 81.2%, valid_acc: 85.2%.
# Minibatch step: 31500, loss: 0.70254, acc: 68.8%, valid_acc: 85.3%.
# Minibatch step: 32000, loss: 0.33384, acc: 87.5%, valid_acc: 85.6%.
# Minibatch step: 32500, loss: 0.96782, acc: 81.2%, valid_acc: 84.9%.
# Minibatch step: 33000, loss: 0.02892, acc: 100.0%, valid_acc: 85.2%.
# Minibatch step: 33500, loss: 0.31241, acc: 87.5%, valid_acc: 85.1%.
# Minibatch step: 34000, loss: 0.14586, acc: 100.0%, valid_acc: 85.1%.
# Minibatch step: 34500, loss: 0.57524, acc: 81.2%, valid_acc: 85.3%.
# Minibatch step: 35000, loss: 0.31022, acc: 87.5%, valid_acc: 85.0%.
# Minibatch step: 35500, loss: 0.17432, acc: 93.8%, valid_acc: 85.3%.
# Minibatch step: 36000, loss: 0.60821, acc: 81.2%, valid_acc: 85.1%.
# Minibatch step: 36500, loss: 0.44064, acc: 87.5%, valid_acc: 85.4%.
# Minibatch step: 37000, loss: 1.14201, acc: 75.0%, valid_acc: 85.6%.
# Minibatch step: 37500, loss: 0.38627, acc: 81.2%, valid_acc: 85.6%.
# Minibatch step: 38000, loss: 0.12957, acc: 100.0%, valid_acc: 85.3%.
# Minibatch step: 38500, loss: 0.48865, acc: 87.5%, valid_acc: 85.7%.
# Minibatch step: 39000, loss: 0.31111, acc: 93.8%, valid_acc: 85.7%.
# Minibatch step: 39500, loss: 0.43903, acc: 81.2%, valid_acc: 84.9%.
# Minibatch step: 40000, loss: 0.11442, acc: 100.0%, valid_acc: 84.9%.
# Minibatch step: 40500, loss: 0.88672, acc: 75.0%, valid_acc: 85.9%.
# Minibatch step: 41000, loss: 0.17358, acc: 93.8%, valid_acc: 85.5%.
# Minibatch step: 41500, loss: 0.44342, acc: 81.2%, valid_acc: 85.6%.
# Minibatch step: 42000, loss: 0.15718, acc: 93.8%, valid_acc: 85.5%.
# Minibatch step: 42500, loss: 0.59426, acc: 93.8%, valid_acc: 85.3%.
# Minibatch step: 43000, loss: 0.21678, acc: 93.8%, valid_acc: 85.0%.
# Minibatch step: 43500, loss: 0.56253, acc: 87.5%, valid_acc: 85.5%.
# Minibatch step: 44000, loss: 0.33195, acc: 87.5%, valid_acc: 85.5%.
# Minibatch step: 44500, loss: 0.16790, acc: 93.8%, valid_acc: 85.7%.
# Minibatch step: 45000, loss: 0.94883, acc: 75.0%, valid_acc: 85.6%.
# Minibatch step: 45500, loss: 0.11102, acc: 100.0%, valid_acc: 85.7%.
# Minibatch step: 46000, loss: 0.11051, acc: 93.8%, valid_acc: 85.5%.
# Minibatch step: 46500, loss: 0.08547, acc: 100.0%, valid_acc: 85.7%.
# Minibatch step: 47000, loss: 0.35526, acc: 87.5%, valid_acc: 85.9%.
# Minibatch step: 47500, loss: 0.22271, acc: 93.8%, valid_acc: 85.8%.
# Minibatch step: 48000, loss: 0.49235, acc: 87.5%, valid_acc: 86.2%.
# Minibatch step: 48500, loss: 0.79646, acc: 68.8%, valid_acc: 85.6%.
# Minibatch step: 49000, loss: 0.69093, acc: 75.0%, valid_acc: 85.8%.
# Minibatch step: 49500, loss: 0.50962, acc: 87.5%, valid_acc: 85.7%.
# Minibatch step: 50000, loss: 0.84258, acc: 81.2%, valid_acc: 85.3%.
# Minibatch step: 50500, loss: 0.99755, acc: 75.0%, valid_acc: 86.0%.
# Minibatch step: 51000, loss: 0.18477, acc: 93.8%, valid_acc: 85.7%.
# Minibatch step: 51500, loss: 0.03883, acc: 100.0%, valid_acc: 86.0%.
# Minibatch step: 52000, loss: 0.34543, acc: 93.8%, valid_acc: 85.8%.
# Minibatch step: 52500, loss: 1.77633, acc: 81.2%, valid_acc: 84.7%.
# Minibatch step: 53000, loss: 0.22316, acc: 93.8%, valid_acc: 86.0%.
# Minibatch step: 53500, loss: 0.27194, acc: 87.5%, valid_acc: 85.2%.
# Minibatch step: 54000, loss: 0.21895, acc: 93.8%, valid_acc: 85.8%.
# Minibatch step: 54500, loss: 1.00560, acc: 75.0%, valid_acc: 85.6%.
# Minibatch step: 55000, loss: 0.70868, acc: 75.0%, valid_acc: 85.4%.
# Minibatch step: 55500, loss: 0.55798, acc: 81.2%, valid_acc: 85.9%.
# Minibatch step: 56000, loss: 0.38150, acc: 87.5%, valid_acc: 86.0%.
# Minibatch step: 56500, loss: 0.94917, acc: 75.0%, valid_acc: 86.1%.
# Minibatch step: 57000, loss: 0.35176, acc: 87.5%, valid_acc: 86.2%.
# Minibatch step: 57500, loss: 0.33792, acc: 87.5%, valid_acc: 85.8%.
# Minibatch step: 58000, loss: 0.53532, acc: 75.0%, valid_acc: 86.4%.
# Minibatch step: 58500, loss: 0.08773, acc: 93.8%, valid_acc: 85.9%.
# Minibatch step: 59000, loss: 0.32725, acc: 87.5%, valid_acc: 85.9%.
# Minibatch step: 59500, loss: 0.10127, acc: 93.8%, valid_acc: 85.8%.
# Minibatch step: 60000, loss: 0.38382, acc: 87.5%, valid_acc: 86.2%.
# Minibatch step: 60500, loss: 0.59075, acc: 75.0%, valid_acc: 85.6%.
# Minibatch step: 61000, loss: 0.50955, acc: 75.0%, valid_acc: 85.6%.
# Minibatch step: 61500, loss: 0.53470, acc: 87.5%, valid_acc: 86.4%.
# Minibatch step: 62000, loss: 0.60770, acc: 81.2%, valid_acc: 85.8%.
# Minibatch step: 62500, loss: 0.27533, acc: 93.8%, valid_acc: 86.2%.
# Minibatch step: 63000, loss: 0.71180, acc: 81.2%, valid_acc: 85.2%.
# Minibatch step: 63500, loss: 0.18595, acc: 93.8%, valid_acc: 86.2%.
# Minibatch step: 64000, loss: 0.84854, acc: 75.0%, valid_acc: 86.1%.
# Minibatch step: 64500, loss: 1.28051, acc: 75.0%, valid_acc: 85.7%.
# Minibatch step: 65000, loss: 0.46141, acc: 81.2%, valid_acc: 85.5%.
# Minibatch step: 65500, loss: 0.22123, acc: 93.8%, valid_acc: 86.5%.
# Minibatch step: 66000, loss: 0.27363, acc: 87.5%, valid_acc: 85.7%.
# Minibatch step: 66500, loss: 0.71987, acc: 75.0%, valid_acc: 86.2%.
# Minibatch step: 67000, loss: 0.91748, acc: 68.8%, valid_acc: 86.5%.
# Minibatch step: 67500, loss: 0.31753, acc: 93.8%, valid_acc: 86.0%.
# Minibatch step: 68000, loss: 0.70206, acc: 93.8%, valid_acc: 86.2%.
# Minibatch step: 68500, loss: 0.23139, acc: 87.5%, valid_acc: 86.2%.
# Minibatch step: 69000, loss: 0.11488, acc: 93.8%, valid_acc: 86.3%.
# Minibatch step: 69500, loss: 0.54952, acc: 75.0%, valid_acc: 86.9%.
# Minibatch step: 70000, loss: 0.55555, acc: 81.2%, valid_acc: 84.7%.
# Minibatch step: 70500, loss: 0.62431, acc: 81.2%, valid_acc: 86.4%.
# Minibatch step: 71000, loss: 0.32670, acc: 87.5%, valid_acc: 86.0%.
# Minibatch step: 71500, loss: 0.16621, acc: 100.0%, valid_acc: 86.4%.
# Minibatch step: 72000, loss: 0.53147, acc: 87.5%, valid_acc: 86.6%.
# Minibatch step: 72500, loss: 0.47505, acc: 87.5%, valid_acc: 86.0%.
# Minibatch step: 73000, loss: 0.50016, acc: 87.5%, valid_acc: 86.6%.
# Minibatch step: 73500, loss: 0.08372, acc: 100.0%, valid_acc: 86.2%.
# Minibatch step: 74000, loss: 0.56001, acc: 87.5%, valid_acc: 86.6%.
# Minibatch step: 74500, loss: 0.30437, acc: 87.5%, valid_acc: 86.2%.
# Minibatch step: 75000, loss: 1.24796, acc: 68.8%, valid_acc: 86.5%.
# Minibatch step: 75500, loss: 0.11966, acc: 93.8%, valid_acc: 86.5%.
# Minibatch step: 76000, loss: 0.57402, acc: 81.2%, valid_acc: 86.8%.
# Minibatch step: 76500, loss: 0.40589, acc: 87.5%, valid_acc: 86.5%.
# Minibatch step: 77000, loss: 0.86247, acc: 81.2%, valid_acc: 86.2%.
# Minibatch step: 77500, loss: 0.46617, acc: 81.2%, valid_acc: 85.2%.
# Minibatch step: 78000, loss: 0.33036, acc: 81.2%, valid_acc: 86.4%.
# Minibatch step: 78500, loss: 0.22993, acc: 87.5%, valid_acc: 85.9%.
# Minibatch step: 79000, loss: 0.09849, acc: 100.0%, valid_acc: 86.0%.
# Minibatch step: 79500, loss: 0.16004, acc: 93.8%, valid_acc: 86.0%.
# Minibatch step: 80000, loss: 0.22178, acc: 93.8%, valid_acc: 86.0%.
# Minibatch step: 80500, loss: 0.80846, acc: 81.2%, valid_acc: 86.4%.
# Minibatch step: 81000, loss: 0.27774, acc: 93.8%, valid_acc: 86.2%.
# Minibatch step: 81500, loss: 0.21619, acc: 87.5%, valid_acc: 86.5%.
# Minibatch step: 82000, loss: 0.51284, acc: 87.5%, valid_acc: 86.4%.
# Minibatch step: 82500, loss: 0.32320, acc: 87.5%, valid_acc: 84.3%.
# Minibatch step: 83000, loss: 0.33122, acc: 87.5%, valid_acc: 86.4%.
# Minibatch step: 83500, loss: 0.22804, acc: 93.8%, valid_acc: 86.3%.
# Minibatch step: 84000, loss: 0.73283, acc: 81.2%, valid_acc: 86.5%.
# Minibatch step: 84500, loss: 0.37516, acc: 87.5%, valid_acc: 86.4%.
# Minibatch step: 85000, loss: 0.28590, acc: 87.5%, valid_acc: 86.6%.
# Minibatch step: 85500, loss: 0.69585, acc: 75.0%, valid_acc: 86.7%.
# Minibatch step: 86000, loss: 0.06885, acc: 100.0%, valid_acc: 86.3%.
# Minibatch step: 86500, loss: 0.47311, acc: 87.5%, valid_acc: 86.4%.
# Minibatch step: 87000, loss: 0.63266, acc: 81.2%, valid_acc: 86.7%.
# Minibatch step: 87500, loss: 0.49657, acc: 87.5%, valid_acc: 86.7%.
# Minibatch step: 88000, loss: 0.28609, acc: 87.5%, valid_acc: 86.6%.
# Minibatch step: 88500, loss: 0.37387, acc: 93.8%, valid_acc: 85.9%.
# Minibatch step: 89000, loss: 0.26846, acc: 93.8%, valid_acc: 86.7%.
# Minibatch step: 89500, loss: 0.54412, acc: 75.0%, valid_acc: 85.9%.
# Minibatch step: 90000, loss: 0.37104, acc: 93.8%, valid_acc: 86.1%.
# Minibatch step: 90500, loss: 0.49266, acc: 81.2%, valid_acc: 86.5%.
# Minibatch step: 91000, loss: 0.97506, acc: 75.0%, valid_acc: 86.1%.
# Minibatch step: 91500, loss: 0.18683, acc: 93.8%, valid_acc: 86.9%.
# Minibatch step: 92000, loss: 0.32048, acc: 100.0%, valid_acc: 86.8%.
# Minibatch step: 92500, loss: 0.07685, acc: 100.0%, valid_acc: 86.4%.
# Minibatch step: 93000, loss: 0.66044, acc: 87.5%, valid_acc: 86.7%.
# Minibatch step: 93500, loss: 0.38000, acc: 81.2%, valid_acc: 86.6%.
# Minibatch step: 94000, loss: 0.32312, acc: 87.5%, valid_acc: 86.7%.
# Minibatch step: 94500, loss: 0.42029, acc: 87.5%, valid_acc: 86.8%.
# Minibatch step: 95000, loss: 0.92793, acc: 75.0%, valid_acc: 84.4%.
# Minibatch step: 95500, loss: 0.15141, acc: 93.8%, valid_acc: 86.9%.
# Minibatch step: 96000, loss: 0.03335, acc: 100.0%, valid_acc: 86.4%.
# Minibatch step: 96500, loss: 0.37974, acc: 87.5%, valid_acc: 86.4%.
# Minibatch step: 97000, loss: 0.11164, acc: 93.8%, valid_acc: 86.5%.
# Minibatch step: 97500, loss: 0.30985, acc: 93.8%, valid_acc: 86.5%.
# Minibatch step: 98000, loss: 0.97361, acc: 81.2%, valid_acc: 86.7%.
# Minibatch step: 98500, loss: 0.12603, acc: 93.8%, valid_acc: 86.6%.
# Minibatch step: 99000, loss: 0.18879, acc: 93.8%, valid_acc: 86.7%.
# Minibatch step: 99500, loss: 0.27833, acc: 87.5%, valid_acc: 87.0%.
# Minibatch step: 100000, loss: 0.67686, acc: 81.2%, valid_acc: 86.8%.
# Test Accuracy: 92.5%

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# x轴是以对数的底的值log(x).
# plt.plot 绘制折线图.
plt.semilogx(step_val, accuracy_val)
plt.grid(True)
plt.title('Test accuracy by Regularization (Logistic)')
plt.show()

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():
    # Input data.
    # tf_train_dataset: (16, 28, 28, 1)
    tf_train_dataset = tf.placeholder(dtype=tf.float32,
                                     shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(dtype=tf.float32,
                                    shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    
    # kernel: [5, 5, 1, 16], stride=2, padding=same
    # lay1_weights: [16, 14, 14, 16]
    lay1_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, num_channels, depth], stddev=0.1))
    lay1_biases = tf.Variable(tf.zeros([lay1_weights.shape[-1]]))
    # conv kernel = [k_width, k_height, channel, k_num]
    # The channel size must be equal to the input's channel.
    
    # kernel: [5, 5, 16, 16], stride=2, padding=same
    # lay2_weights: [16, 7, 7, 16]
    lay2_weights = tf.Variable(
        tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    lay2_biases = tf.Variable(tf.zeros(depth))
    
    # Fully connect: [16, 7*7*16] * [7*7*16, num_hidden]
    # Output: [16, num_hidden]
    lay3_weights = tf.Variable(
        tf.truncated_normal([image_size // 4 * image_size // 4 * depth, num_hidden]))
    lay3_biases = tf.Variable(tf.zeros(num_hidden))
    
    # [16, num_hidden] * [num_hidden, num_labels]
    # Output: [16, num_labels]
    lay4_weights = tf.Variable(
        tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    lay4_biases = tf.Variable(tf.constant(1., shape=[num_labels]))
    
    def model(data):
        # The first convolutional layer.
        # input: [batch_size, img_height, img_width, channel]
        # output: [16, 28, 28, 16] -> convolutional kernel * 16
        conv = tf.nn.conv2d(input=data, 
                            filter=lay1_weights,
                            strides=[1,1,1,1],
                            padding='SAME')
        # Activation Function: Relu.
        hidden = tf.nn.relu(conv + lay1_biases)
        
        # stride 2 and kernel size 2.
        # input: [16, 28, 28, 16]
        # output: [16, 14, 14, 16] -> strides=2
        pool1 = tf.nn.max_pool(value=hidden, 
                               ksize=[1,2,2,1], 
                               strides=[1,2,2,1],
                               padding='SAME')
        
        
        # The second convolutional layer.
        # input: [16, 14, 14, 16], conv kernel: [5, 5], strides=2, padding=same
        # output: [16, 14, 14, 16] -> 7/2 = 3.5 -> 4
        conv = tf.nn.conv2d(input=pool1,
                           filter=lay2_weights,
                           strides=[1,1,1,1],
                           padding='SAME')
        hidden = tf.nn.relu(conv + lay2_biases)
        
        # pooling layer 2:
        # input: [16, 14, 14, 16]
        # output:  [16, 7, 7, 16]
        pool2 = tf.nn.max_pool(value=hidden, 
                               ksize=[1,2,2,1],
                               strides=[1,2,2,1],
                               padding='SAME')
        
        # shape: [16, 7, 7, 16]
        shape = pool2.get_shape().as_list()
        reshape = tf.reshape(tensor=pool2,
                            shape=[shape[0], shape[1]*shape[2]*shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, lay3_weights) + lay3_biases)
        return tf.matmul(hidden, lay4_weights) + lay4_biases
    
    # Training computation
    _logits = model(tf_train_dataset)
    _loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits_v2(labels=tf_train_labels,
                                                logits=_logits))
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(_loss)
    
    # Predictions for the training.
    train_prediction = tf.nn.softmax(_logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
steps = 100000
step_val = []
accuracy_val = []

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('[Tensorflow]: Initialized!')
    for step in range(steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        
        # Generate minibatch.
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        
        # Feed it.
        feed_dict = {tf_train_dataset: batch_data, 
                     tf_train_labels: batch_labels}
        
        _, loss, predictions = session.run([optimizer, 
                                                _loss, 
                                                train_prediction], feed_dict=feed_dict)
            
        if ((step+1) % 500 == 0):
            print('Minibatch step: %d, loss: %4.5f, acc: %.1f%%, valid_acc: %.1f%%.'
                  % ((step+1), loss,
                     accuracy(predictions, batch_labels), 
                     accuracy(valid_prediction.eval(), valid_labels)))
            step_val.append(step+1)
            accuracy_val.append(loss)
    print('Test Accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# [Tensorflow]: Initialized!
# Minibatch step: 500, loss: 0.94739, acc: 56.2%, valid_acc: 74.4%.
# Minibatch step: 1000, loss: 0.91693, acc: 75.0%, valid_acc: 76.4%.
# Minibatch step: 1500, loss: 0.93654, acc: 75.0%, valid_acc: 76.6%.
# Minibatch step: 2000, loss: 0.05102, acc: 100.0%, valid_acc: 79.5%.
# Minibatch step: 2500, loss: 1.05590, acc: 68.8%, valid_acc: 81.2%.
# Minibatch step: 3000, loss: 1.38465, acc: 56.2%, valid_acc: 80.3%.
# Minibatch step: 3500, loss: 0.44936, acc: 87.5%, valid_acc: 81.9%.
# Minibatch step: 4000, loss: 0.89432, acc: 87.5%, valid_acc: 79.4%.
# Minibatch step: 4500, loss: 0.60454, acc: 75.0%, valid_acc: 81.1%.
# Minibatch step: 5000, loss: 0.42764, acc: 87.5%, valid_acc: 81.7%.
# Minibatch step: 5500, loss: 0.21834, acc: 93.8%, valid_acc: 82.8%.
# Minibatch step: 6000, loss: 0.62656, acc: 81.2%, valid_acc: 82.5%.
# Minibatch step: 6500, loss: 0.35032, acc: 87.5%, valid_acc: 82.9%.
# Minibatch step: 7000, loss: 0.76387, acc: 75.0%, valid_acc: 83.2%.
# Minibatch step: 7500, loss: 0.72060, acc: 87.5%, valid_acc: 78.6%.
# Minibatch step: 8000, loss: 0.73170, acc: 68.8%, valid_acc: 81.6%.
# Minibatch step: 8500, loss: 0.54343, acc: 93.8%, valid_acc: 83.3%.
# Minibatch step: 9000, loss: 1.37432, acc: 75.0%, valid_acc: 80.6%.
# Minibatch step: 9500, loss: 0.73011, acc: 75.0%, valid_acc: 83.6%.
# Minibatch step: 10000, loss: 0.62499, acc: 81.2%, valid_acc: 83.7%.
# Minibatch step: 10500, loss: 0.52086, acc: 87.5%, valid_acc: 82.5%.
# Minibatch step: 11000, loss: 0.63349, acc: 87.5%, valid_acc: 83.3%.
# Minibatch step: 11500, loss: 0.33649, acc: 87.5%, valid_acc: 83.5%.
# Minibatch step: 12000, loss: 0.07684, acc: 93.8%, valid_acc: 83.5%.
# Minibatch step: 12500, loss: 0.32449, acc: 87.5%, valid_acc: 83.6%.
# Minibatch step: 13000, loss: 0.91871, acc: 75.0%, valid_acc: 83.2%.
# Minibatch step: 13500, loss: 0.09161, acc: 100.0%, valid_acc: 84.1%.
# Minibatch step: 14000, loss: 0.70276, acc: 75.0%, valid_acc: 83.3%.
# Minibatch step: 14500, loss: 0.24935, acc: 93.8%, valid_acc: 83.2%.
# Minibatch step: 15000, loss: 0.38232, acc: 87.5%, valid_acc: 84.3%.
# Minibatch step: 15500, loss: 1.04373, acc: 81.2%, valid_acc: 83.4%.
# Minibatch step: 16000, loss: 0.51338, acc: 87.5%, valid_acc: 83.8%.
# Minibatch step: 16500, loss: 0.21857, acc: 93.8%, valid_acc: 83.1%.
# Minibatch step: 17000, loss: 0.17870, acc: 100.0%, valid_acc: 84.7%.
# Minibatch step: 17500, loss: 0.73510, acc: 87.5%, valid_acc: 84.3%.
# Minibatch step: 18000, loss: 0.31899, acc: 93.8%, valid_acc: 84.7%.
# Minibatch step: 18500, loss: 0.67190, acc: 75.0%, valid_acc: 84.2%.
# Minibatch step: 19000, loss: 0.12813, acc: 100.0%, valid_acc: 84.5%.
# Minibatch step: 19500, loss: 0.28084, acc: 87.5%, valid_acc: 84.7%.
# Minibatch step: 20000, loss: 1.06014, acc: 62.5%, valid_acc: 84.2%.
# Minibatch step: 20500, loss: 0.27699, acc: 87.5%, valid_acc: 84.9%.
# Minibatch step: 21000, loss: 0.29287, acc: 93.8%, valid_acc: 85.0%.
# Minibatch step: 21500, loss: 0.68178, acc: 75.0%, valid_acc: 83.8%.
# Minibatch step: 22000, loss: 0.17655, acc: 93.8%, valid_acc: 84.9%.
# Minibatch step: 22500, loss: 0.32605, acc: 87.5%, valid_acc: 84.7%.
# Minibatch step: 23000, loss: 0.70947, acc: 81.2%, valid_acc: 84.9%.
# Minibatch step: 23500, loss: 0.78641, acc: 75.0%, valid_acc: 85.0%.
# Minibatch step: 24000, loss: 0.59768, acc: 81.2%, valid_acc: 85.0%.
# Minibatch step: 24500, loss: 0.11798, acc: 93.8%, valid_acc: 84.7%.
# Minibatch step: 25000, loss: 0.98467, acc: 68.8%, valid_acc: 84.0%.
# Minibatch step: 25500, loss: 0.13345, acc: 100.0%, valid_acc: 84.4%.
# Minibatch step: 26000, loss: 0.75721, acc: 81.2%, valid_acc: 85.3%.
# Minibatch step: 26500, loss: 0.97502, acc: 62.5%, valid_acc: 84.9%.
# Minibatch step: 27000, loss: 0.83984, acc: 75.0%, valid_acc: 82.8%.
# Minibatch step: 27500, loss: 0.47059, acc: 81.2%, valid_acc: 85.2%.
# Minibatch step: 28000, loss: 0.45080, acc: 75.0%, valid_acc: 84.9%.
# Minibatch step: 28500, loss: 0.76917, acc: 81.2%, valid_acc: 84.8%.
# Minibatch step: 29000, loss: 0.61136, acc: 81.2%, valid_acc: 85.0%.
# Minibatch step: 29500, loss: 0.75261, acc: 75.0%, valid_acc: 85.8%.
# Minibatch step: 30000, loss: 0.43335, acc: 93.8%, valid_acc: 85.1%.
# Minibatch step: 30500, loss: 0.79707, acc: 81.2%, valid_acc: 85.0%.
# Minibatch step: 31000, loss: 0.88407, acc: 68.8%, valid_acc: 85.2%.
# Minibatch step: 31500, loss: 0.50361, acc: 81.2%, valid_acc: 85.5%.
# Minibatch step: 32000, loss: 0.33584, acc: 87.5%, valid_acc: 85.4%.
# Minibatch step: 32500, loss: 0.75670, acc: 87.5%, valid_acc: 85.1%.
# Minibatch step: 33000, loss: 0.12970, acc: 93.8%, valid_acc: 85.3%.
# Minibatch step: 33500, loss: 0.35726, acc: 81.2%, valid_acc: 85.5%.
# Minibatch step: 34000, loss: 0.22325, acc: 87.5%, valid_acc: 85.0%.
# Minibatch step: 34500, loss: 0.69031, acc: 75.0%, valid_acc: 85.7%.
# Minibatch step: 35000, loss: 0.36711, acc: 87.5%, valid_acc: 85.3%.
# Minibatch step: 35500, loss: 0.21898, acc: 93.8%, valid_acc: 85.2%.
# Minibatch step: 36000, loss: 0.70223, acc: 68.8%, valid_acc: 86.1%.
# Minibatch step: 36500, loss: 0.32339, acc: 93.8%, valid_acc: 86.1%.
# Minibatch step: 37000, loss: 0.93517, acc: 68.8%, valid_acc: 85.0%.
# Minibatch step: 37500, loss: 0.43308, acc: 87.5%, valid_acc: 85.5%.
# Minibatch step: 38000, loss: 0.06969, acc: 100.0%, valid_acc: 85.6%.
# Minibatch step: 38500, loss: 0.33066, acc: 93.8%, valid_acc: 85.9%.
# Minibatch step: 39000, loss: 0.33936, acc: 87.5%, valid_acc: 85.3%.
# Minibatch step: 39500, loss: 0.16598, acc: 93.8%, valid_acc: 85.9%.
# Minibatch step: 40000, loss: 0.35222, acc: 93.8%, valid_acc: 85.9%.
# Minibatch step: 40500, loss: 0.71853, acc: 75.0%, valid_acc: 85.8%.
# Minibatch step: 41000, loss: 0.15194, acc: 93.8%, valid_acc: 86.0%.
# Minibatch step: 41500, loss: 0.59275, acc: 81.2%, valid_acc: 85.5%.
# Minibatch step: 42000, loss: 0.10384, acc: 93.8%, valid_acc: 85.6%.
# Minibatch step: 42500, loss: 0.52808, acc: 87.5%, valid_acc: 85.8%.
# Minibatch step: 43000, loss: 0.24946, acc: 93.8%, valid_acc: 85.8%.
# Minibatch step: 43500, loss: 0.76389, acc: 75.0%, valid_acc: 85.8%.
# Minibatch step: 44000, loss: 0.27303, acc: 93.8%, valid_acc: 86.1%.
# Minibatch step: 44500, loss: 0.18207, acc: 100.0%, valid_acc: 85.9%.
# Minibatch step: 45000, loss: 0.67443, acc: 75.0%, valid_acc: 86.3%.
# Minibatch step: 45500, loss: 0.23626, acc: 93.8%, valid_acc: 86.6%.
# Minibatch step: 46000, loss: 0.17465, acc: 93.8%, valid_acc: 85.7%.
# Minibatch step: 46500, loss: 0.36180, acc: 87.5%, valid_acc: 85.5%.
# Minibatch step: 47000, loss: 0.27371, acc: 100.0%, valid_acc: 85.7%.
# Minibatch step: 47500, loss: 0.24311, acc: 93.8%, valid_acc: 86.3%.
# Minibatch step: 48000, loss: 0.16657, acc: 93.8%, valid_acc: 85.8%.
# Minibatch step: 48500, loss: 1.00087, acc: 62.5%, valid_acc: 84.6%.
# Minibatch step: 49000, loss: 0.67754, acc: 81.2%, valid_acc: 86.1%.
# Minibatch step: 49500, loss: 0.59799, acc: 81.2%, valid_acc: 85.6%.
# Minibatch step: 50000, loss: 0.72100, acc: 81.2%, valid_acc: 85.7%.
# Minibatch step: 50500, loss: 0.83677, acc: 81.2%, valid_acc: 86.1%.
# Minibatch step: 51000, loss: 0.25256, acc: 87.5%, valid_acc: 86.1%.
# Minibatch step: 51500, loss: 0.09288, acc: 100.0%, valid_acc: 85.8%.
# Minibatch step: 52000, loss: 0.45584, acc: 93.8%, valid_acc: 85.6%.
# Minibatch step: 52500, loss: 1.00600, acc: 81.2%, valid_acc: 85.0%.
# Minibatch step: 53000, loss: 0.21595, acc: 93.8%, valid_acc: 86.1%.
# Minibatch step: 53500, loss: 0.17742, acc: 93.8%, valid_acc: 86.7%.
# Minibatch step: 54000, loss: 0.56875, acc: 81.2%, valid_acc: 86.0%.
# Minibatch step: 54500, loss: 0.52124, acc: 75.0%, valid_acc: 86.1%.
# Minibatch step: 55000, loss: 0.67858, acc: 81.2%, valid_acc: 85.9%.
# Minibatch step: 55500, loss: 0.37532, acc: 87.5%, valid_acc: 86.1%.
# Minibatch step: 56000, loss: 0.57486, acc: 87.5%, valid_acc: 86.1%.
# Minibatch step: 56500, loss: 0.52544, acc: 81.2%, valid_acc: 85.0%.
# Minibatch step: 57000, loss: 0.34734, acc: 87.5%, valid_acc: 86.4%.
# Minibatch step: 57500, loss: 0.35722, acc: 87.5%, valid_acc: 86.3%.
# Minibatch step: 58000, loss: 0.57712, acc: 81.2%, valid_acc: 86.8%.
# Minibatch step: 58500, loss: 0.14414, acc: 93.8%, valid_acc: 85.9%.
# Minibatch step: 59000, loss: 0.45040, acc: 81.2%, valid_acc: 86.1%.
# Minibatch step: 59500, loss: 0.15257, acc: 93.8%, valid_acc: 86.4%.
# Minibatch step: 60000, loss: 0.85271, acc: 81.2%, valid_acc: 86.4%.
# Minibatch step: 60500, loss: 0.41934, acc: 87.5%, valid_acc: 86.1%.
# Minibatch step: 61000, loss: 0.43270, acc: 81.2%, valid_acc: 86.3%.
# Minibatch step: 61500, loss: 0.30316, acc: 87.5%, valid_acc: 86.3%.
# Minibatch step: 62000, loss: 0.90870, acc: 68.8%, valid_acc: 86.1%.
# Minibatch step: 62500, loss: 0.35693, acc: 87.5%, valid_acc: 86.0%.
# Minibatch step: 63000, loss: 0.44475, acc: 81.2%, valid_acc: 86.0%.
# Minibatch step: 63500, loss: 0.27092, acc: 93.8%, valid_acc: 86.1%.
# Minibatch step: 64000, loss: 0.58707, acc: 81.2%, valid_acc: 86.3%.
# Minibatch step: 64500, loss: 0.95020, acc: 68.8%, valid_acc: 85.6%.
# Minibatch step: 65000, loss: 0.75115, acc: 81.2%, valid_acc: 86.4%.
# Minibatch step: 65500, loss: 0.22698, acc: 93.8%, valid_acc: 86.5%.
# Minibatch step: 66000, loss: 0.33602, acc: 87.5%, valid_acc: 86.7%.
# Minibatch step: 66500, loss: 0.77607, acc: 81.2%, valid_acc: 86.6%.
# Minibatch step: 67000, loss: 0.92650, acc: 68.8%, valid_acc: 86.1%.
# Minibatch step: 67500, loss: 0.33428, acc: 81.2%, valid_acc: 85.6%.
# Minibatch step: 68000, loss: 0.61578, acc: 81.2%, valid_acc: 86.4%.
# Minibatch step: 68500, loss: 0.18940, acc: 93.8%, valid_acc: 86.7%.
# Minibatch step: 69000, loss: 0.22638, acc: 87.5%, valid_acc: 86.7%.
# Minibatch step: 69500, loss: 0.80691, acc: 75.0%, valid_acc: 85.9%.
# Minibatch step: 70000, loss: 0.53358, acc: 81.2%, valid_acc: 86.2%.
# Minibatch step: 70500, loss: 0.74001, acc: 81.2%, valid_acc: 87.2%.
# Minibatch step: 71000, loss: 0.44339, acc: 81.2%, valid_acc: 86.4%.
# Minibatch step: 71500, loss: 0.29916, acc: 93.8%, valid_acc: 85.8%.
# Minibatch step: 72000, loss: 0.15768, acc: 93.8%, valid_acc: 86.7%.
# Minibatch step: 72500, loss: 0.59110, acc: 81.2%, valid_acc: 86.6%.
# Minibatch step: 73000, loss: 0.59391, acc: 75.0%, valid_acc: 86.4%.
# Minibatch step: 73500, loss: 0.15261, acc: 93.8%, valid_acc: 86.9%.
# Minibatch step: 74000, loss: 0.57635, acc: 87.5%, valid_acc: 86.6%.
# Minibatch step: 74500, loss: 0.45457, acc: 87.5%, valid_acc: 86.7%.
# Minibatch step: 75000, loss: 1.09086, acc: 75.0%, valid_acc: 86.3%.
# Minibatch step: 75500, loss: 0.05602, acc: 100.0%, valid_acc: 86.4%.
# Minibatch step: 76000, loss: 0.59519, acc: 75.0%, valid_acc: 86.8%.
# Minibatch step: 76500, loss: 0.26578, acc: 93.8%, valid_acc: 86.6%.
# Minibatch step: 77000, loss: 1.08421, acc: 81.2%, valid_acc: 86.4%.
# Minibatch step: 77500, loss: 0.42747, acc: 87.5%, valid_acc: 87.0%.
# Minibatch step: 78000, loss: 0.30437, acc: 87.5%, valid_acc: 87.1%.
# Minibatch step: 78500, loss: 0.09810, acc: 100.0%, valid_acc: 87.1%.
# Minibatch step: 79000, loss: 0.36599, acc: 87.5%, valid_acc: 86.6%.
# Minibatch step: 79500, loss: 0.08783, acc: 100.0%, valid_acc: 86.2%.
# Minibatch step: 80000, loss: 0.20165, acc: 93.8%, valid_acc: 86.6%.
# Minibatch step: 80500, loss: 0.79011, acc: 93.8%, valid_acc: 86.4%.
# Minibatch step: 81000, loss: 0.37519, acc: 87.5%, valid_acc: 86.5%.
# Minibatch step: 81500, loss: 0.21453, acc: 87.5%, valid_acc: 87.3%.
# Minibatch step: 82000, loss: 0.47622, acc: 81.2%, valid_acc: 86.4%.
# Minibatch step: 82500, loss: 0.22364, acc: 93.8%, valid_acc: 86.1%.
# Minibatch step: 83000, loss: 0.24299, acc: 93.8%, valid_acc: 87.3%.
# Minibatch step: 83500, loss: 0.13545, acc: 93.8%, valid_acc: 86.4%.
# Minibatch step: 84000, loss: 0.59390, acc: 75.0%, valid_acc: 86.6%.
# Minibatch step: 84500, loss: 0.53565, acc: 87.5%, valid_acc: 86.8%.
# Minibatch step: 85000, loss: 0.21446, acc: 87.5%, valid_acc: 86.6%.
# Minibatch step: 85500, loss: 0.71101, acc: 81.2%, valid_acc: 86.7%.
# Minibatch step: 86000, loss: 0.16186, acc: 93.8%, valid_acc: 87.1%.
# Minibatch step: 86500, loss: 0.77889, acc: 87.5%, valid_acc: 86.8%.
# Minibatch step: 87000, loss: 0.77592, acc: 81.2%, valid_acc: 86.8%.
# Minibatch step: 87500, loss: 0.39271, acc: 87.5%, valid_acc: 86.4%.
# Minibatch step: 88000, loss: 0.38757, acc: 87.5%, valid_acc: 86.8%.
# Minibatch step: 88500, loss: 0.40780, acc: 93.8%, valid_acc: 86.6%.
# Minibatch step: 89000, loss: 0.18940, acc: 87.5%, valid_acc: 84.8%.
# Minibatch step: 89500, loss: 0.57177, acc: 75.0%, valid_acc: 86.3%.
# Minibatch step: 90000, loss: 0.37533, acc: 93.8%, valid_acc: 87.0%.
# Minibatch step: 90500, loss: 0.59835, acc: 81.2%, valid_acc: 86.7%.
# Minibatch step: 91000, loss: 0.86195, acc: 87.5%, valid_acc: 86.9%.
# Minibatch step: 91500, loss: 0.16948, acc: 93.8%, valid_acc: 86.7%.
# Minibatch step: 92000, loss: 0.38260, acc: 87.5%, valid_acc: 86.3%.
# Minibatch step: 92500, loss: 0.04013, acc: 100.0%, valid_acc: 86.6%.
# Minibatch step: 93000, loss: 0.68739, acc: 87.5%, valid_acc: 87.0%.
# Minibatch step: 93500, loss: 0.32843, acc: 93.8%, valid_acc: 86.8%.
# Minibatch step: 94000, loss: 0.59136, acc: 81.2%, valid_acc: 87.4%.
# Minibatch step: 94500, loss: 0.47210, acc: 87.5%, valid_acc: 86.9%.
# Minibatch step: 95000, loss: 0.85316, acc: 75.0%, valid_acc: 86.8%.
# Minibatch step: 95500, loss: 0.22254, acc: 87.5%, valid_acc: 87.8%.
# Minibatch step: 96000, loss: 0.05782, acc: 100.0%, valid_acc: 87.2%.
# Minibatch step: 96500, loss: 0.45498, acc: 87.5%, valid_acc: 86.8%.
# Minibatch step: 97000, loss: 0.06255, acc: 93.8%, valid_acc: 87.1%.
# Minibatch step: 97500, loss: 0.41154, acc: 81.2%, valid_acc: 87.0%.
# Minibatch step: 98000, loss: 0.67776, acc: 68.8%, valid_acc: 86.8%.
# Minibatch step: 98500, loss: 0.17495, acc: 100.0%, valid_acc: 87.4%.
# Minibatch step: 99000, loss: 0.25223, acc: 93.8%, valid_acc: 86.4%.
# Minibatch step: 99500, loss: 0.61533, acc: 81.2%, valid_acc: 87.1%.
# Minibatch step: 100000, loss: 0.62167, acc: 81.2%, valid_acc: 87.0%.
# Test Accuracy: 92.7%

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# x轴是以对数的底的值log(x).
# plt.plot 绘制折线图.
plt.semilogx(step_val, accuracy_val)
plt.grid(True)
plt.title('Test accuracy by Regularization (Logistic)')
plt.show()

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %% [markdown]
# The CNN below is loosely inspired by the LeNet5 architecture.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():
    # Input data.
    # tf_train_dataset: (16, 28, 28, 1)
    tf_train_dataset = tf.placeholder(dtype=tf.float32,
                                     shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(dtype=tf.float32,
                                    shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)
    
    
    # kernel: [5, 5, 1, 16], stride=2, padding=valid
    lay1_weights = tf.Variable(tf.truncated_normal(
        [patch_size, patch_size, num_channels, depth], stddev=0.1))
    lay1_biases = tf.Variable(tf.zeros([lay1_weights.shape[-1]]))
    # conv kernel = [k_width, k_height, channel, k_num]
    # The channel size must be equal to the input's channel.
    
    # kernel: [5, 5, 16, 16], stride=2, padding=valid
    lay2_weights = tf.Variable(
        tf.truncated_normal([patch_size, patch_size, depth, depth], stddev=0.1))
    lay2_biases = tf.Variable(tf.zeros(depth))
    
    # Fully connect: [7*7*16, num_hidden]
    # Output: [16, num_hidden]
    size3 = ((image_size - patch_size + 1) // 2 - patch_size + 1) // 2
    lay3_weights = tf.Variable(
        tf.truncated_normal([size3 * size3 * depth, num_hidden]))
    lay3_biases = tf.Variable(tf.zeros(num_hidden))
    
    # [num_hidden, num_labels]
    lay4_weights = tf.Variable(
        tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
    lay4_biases = tf.Variable(tf.constant(1., shape=[num_labels]))
    
    def model(data):
        # The first convolutional layer.
        # input: [batch_size, img_height, img_width, channel]
        # output: [16, 24, 24, 16] -> convolutional kernel * 16
        # C1
        conv = tf.nn.conv2d(input=data, 
                            filter=lay1_weights,
                            strides=[1,1,1,1],
                            padding='VALID')
        # Activation Function: Relu.
        hidden = tf.nn.relu(conv + lay1_biases)
        
        # stride 2 and kernel size 2.
        # input: [16, 24, 24, 16]
        # output: [16, 12, 12, 16] -> strides=2
        # S2
        pool1 = tf.nn.avg_pool(value=hidden, 
                               ksize=[1,2,2,1], 
                               strides=[1,2,2,1],
                               padding='VALID')
        
        # The second convolutional layer.
        # input: [16, 12, 12, 16], conv kernel: [5, 5], strides=2, padding=same
        # output: [16, 8, 8, 16]
        # C3
        conv = tf.nn.conv2d(input=pool1,
                           filter=lay2_weights,
                           strides=[1,1,1,1],
                           padding='VALID')
        hidden = tf.nn.relu(conv + lay2_biases)
        
        # pooling layer 2:
        # input: [16, 8, 8, 16]
        # output:  [16, 4, 4, 16]
        # S4
        pool2 = tf.nn.max_pool(value=hidden, 
                               ksize=[1,2,2,1],
                               strides=[1,2,2,1],
                               padding='VALID')
        
        # shape: [16, 4, 4, 16]
        # F5
        shape = pool2.get_shape().as_list()
        reshape = tf.reshape(tensor=pool2,
                            shape=[shape[0], shape[1]*shape[2]*shape[3]])
        hidden = tf.nn.relu(tf.matmul(reshape, lay3_weights) + lay3_biases)
        return tf.matmul(hidden, lay4_weights) + lay4_biases
    
    # Training computation
    _logits = model(tf_train_dataset)
    _loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits_v2(labels=tf_train_labels,
                                                logits=_logits))
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(_loss)
    
    # Predictions for the training.
    train_prediction = tf.nn.softmax(_logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
steps = 100000
step_val = []
accuracy_val = []

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('[Tensorflow]: Initialized!')
    for step in range(steps):
        offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
        
        # Generate minibatch.
        batch_data = train_dataset[offset:(offset + batch_size), :]
        batch_labels = train_labels[offset:(offset + batch_size), :]
        
        # Feed it.
        feed_dict = {tf_train_dataset: batch_data, 
                     tf_train_labels: batch_labels}
        
        _, loss, predictions = session.run([optimizer, 
                                                _loss, 
                                                train_prediction], feed_dict=feed_dict)
            
        if ((step+1) % 500 == 0):
            print('Minibatch step: %d, loss: %4.5f, acc: %.1f%%, valid_acc: %.1f%%.'
                  % ((step+1), loss,
                     accuracy(predictions, batch_labels), 
                     accuracy(valid_prediction.eval(), valid_labels)))
            step_val.append(step+1)
            accuracy_val.append(loss)
    print('Test Accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# [Tensorflow]: Initialized!
# Minibatch step: 500, loss: 0.63997, acc: 75.0%, valid_acc: 77.1%.
# Minibatch step: 1000, loss: 0.98649, acc: 75.0%, valid_acc: 80.4%.
# Minibatch step: 1500, loss: 0.71715, acc: 75.0%, valid_acc: 81.2%.
# Minibatch step: 2000, loss: 0.10359, acc: 100.0%, valid_acc: 81.4%.
# Minibatch step: 2500, loss: 0.80015, acc: 75.0%, valid_acc: 81.0%.
# Minibatch step: 3000, loss: 1.49320, acc: 62.5%, valid_acc: 81.8%.
# Minibatch step: 3500, loss: 0.50431, acc: 75.0%, valid_acc: 82.2%.
# Minibatch step: 4000, loss: 0.98100, acc: 75.0%, valid_acc: 83.7%.
# Minibatch step: 4500, loss: 0.63293, acc: 81.2%, valid_acc: 82.8%.
# Minibatch step: 5000, loss: 0.89297, acc: 75.0%, valid_acc: 83.4%.
# Minibatch step: 5500, loss: 0.43056, acc: 87.5%, valid_acc: 82.7%.
# Minibatch step: 6000, loss: 0.94969, acc: 62.5%, valid_acc: 84.4%.
# Minibatch step: 6500, loss: 0.73003, acc: 75.0%, valid_acc: 83.3%.
# Minibatch step: 7000, loss: 0.53805, acc: 81.2%, valid_acc: 83.8%.
# Minibatch step: 7500, loss: 0.56240, acc: 87.5%, valid_acc: 83.7%.
# Minibatch step: 8000, loss: 0.71728, acc: 75.0%, valid_acc: 84.8%.
# Minibatch step: 8500, loss: 0.57772, acc: 87.5%, valid_acc: 84.2%.
# Minibatch step: 9000, loss: 0.70308, acc: 75.0%, valid_acc: 84.5%.
# Minibatch step: 9500, loss: 0.45254, acc: 87.5%, valid_acc: 84.3%.
# Minibatch step: 10000, loss: 0.27411, acc: 81.2%, valid_acc: 85.1%.
# Minibatch step: 10500, loss: 0.34540, acc: 93.8%, valid_acc: 84.4%.
# Minibatch step: 11000, loss: 0.48075, acc: 87.5%, valid_acc: 84.8%.
# Minibatch step: 11500, loss: 0.18345, acc: 93.8%, valid_acc: 85.1%.
# Minibatch step: 12000, loss: 0.07515, acc: 100.0%, valid_acc: 85.9%.
# Minibatch step: 12500, loss: 0.45764, acc: 87.5%, valid_acc: 84.6%.
# Minibatch step: 13000, loss: 1.27708, acc: 81.2%, valid_acc: 85.3%.
# Minibatch step: 13500, loss: 0.10395, acc: 100.0%, valid_acc: 85.4%.
# Minibatch step: 14000, loss: 0.71618, acc: 75.0%, valid_acc: 84.7%.
# Minibatch step: 14500, loss: 0.16382, acc: 93.8%, valid_acc: 85.0%.
# Minibatch step: 15000, loss: 0.46587, acc: 87.5%, valid_acc: 84.9%.
# Minibatch step: 15500, loss: 0.51496, acc: 87.5%, valid_acc: 86.2%.
# Minibatch step: 16000, loss: 0.30648, acc: 87.5%, valid_acc: 85.9%.
# Minibatch step: 16500, loss: 0.24779, acc: 100.0%, valid_acc: 85.5%.
# Minibatch step: 17000, loss: 0.71126, acc: 81.2%, valid_acc: 85.8%.
# Minibatch step: 17500, loss: 0.55259, acc: 81.2%, valid_acc: 85.4%.
# Minibatch step: 18000, loss: 0.32210, acc: 93.8%, valid_acc: 85.4%.
# Minibatch step: 18500, loss: 0.59201, acc: 75.0%, valid_acc: 85.3%.
# Minibatch step: 19000, loss: 0.37264, acc: 81.2%, valid_acc: 85.8%.
# Minibatch step: 19500, loss: 0.21665, acc: 93.8%, valid_acc: 85.8%.
# Minibatch step: 20000, loss: 2.14013, acc: 37.5%, valid_acc: 78.7%.
# Minibatch step: 20500, loss: 0.54789, acc: 87.5%, valid_acc: 85.4%.
# Minibatch step: 21000, loss: 0.22569, acc: 93.8%, valid_acc: 85.7%.
# Minibatch step: 21500, loss: 0.64550, acc: 81.2%, valid_acc: 86.0%.
# Minibatch step: 22000, loss: 0.49452, acc: 81.2%, valid_acc: 85.1%.
# Minibatch step: 22500, loss: 0.24673, acc: 93.8%, valid_acc: 86.4%.
# Minibatch step: 23000, loss: 0.51077, acc: 81.2%, valid_acc: 85.9%.
# Minibatch step: 23500, loss: 0.75880, acc: 75.0%, valid_acc: 86.6%.
# Minibatch step: 24000, loss: 0.27845, acc: 93.8%, valid_acc: 85.3%.
# Minibatch step: 24500, loss: 0.09420, acc: 100.0%, valid_acc: 86.4%.
# Minibatch step: 25000, loss: 1.06660, acc: 68.8%, valid_acc: 85.8%.
# Minibatch step: 25500, loss: 0.10289, acc: 100.0%, valid_acc: 86.4%.
# Minibatch step: 26000, loss: 0.44015, acc: 81.2%, valid_acc: 86.1%.
# Minibatch step: 26500, loss: 0.53024, acc: 81.2%, valid_acc: 86.0%.
# Minibatch step: 27000, loss: 0.59812, acc: 68.8%, valid_acc: 85.9%.
# Minibatch step: 27500, loss: 0.47846, acc: 81.2%, valid_acc: 86.3%.
# Minibatch step: 28000, loss: 0.33720, acc: 87.5%, valid_acc: 86.4%.
# Minibatch step: 28500, loss: 0.59708, acc: 81.2%, valid_acc: 86.4%.
# Minibatch step: 29000, loss: 0.73773, acc: 68.8%, valid_acc: 86.3%.
# Minibatch step: 29500, loss: 0.36560, acc: 87.5%, valid_acc: 86.3%.
# Minibatch step: 30000, loss: 0.27352, acc: 93.8%, valid_acc: 86.7%.
# Minibatch step: 30500, loss: 0.91235, acc: 75.0%, valid_acc: 86.3%.
# Minibatch step: 31000, loss: 0.88711, acc: 68.8%, valid_acc: 86.0%.
# Minibatch step: 31500, loss: 0.96908, acc: 68.8%, valid_acc: 86.2%.
# Minibatch step: 32000, loss: 0.51564, acc: 87.5%, valid_acc: 85.6%.
# Minibatch step: 32500, loss: 0.33405, acc: 93.8%, valid_acc: 86.5%.
# Minibatch step: 33000, loss: 0.01945, acc: 100.0%, valid_acc: 86.9%.
# Minibatch step: 33500, loss: 0.27260, acc: 93.8%, valid_acc: 86.3%.
# Minibatch step: 34000, loss: 0.22158, acc: 87.5%, valid_acc: 86.6%.
# Minibatch step: 34500, loss: 0.47634, acc: 93.8%, valid_acc: 86.0%.
# Minibatch step: 35000, loss: 0.48682, acc: 81.2%, valid_acc: 86.4%.
# Minibatch step: 35500, loss: 0.21544, acc: 93.8%, valid_acc: 86.2%.
# Minibatch step: 36000, loss: 0.44189, acc: 93.8%, valid_acc: 86.7%.
# Minibatch step: 36500, loss: 0.18347, acc: 100.0%, valid_acc: 86.8%.
# Minibatch step: 37000, loss: 1.28183, acc: 75.0%, valid_acc: 86.3%.
# Minibatch step: 37500, loss: 0.34475, acc: 93.8%, valid_acc: 86.8%.
# Minibatch step: 38000, loss: 0.10313, acc: 100.0%, valid_acc: 86.7%.
# Minibatch step: 38500, loss: 0.16583, acc: 93.8%, valid_acc: 86.8%.
# Minibatch step: 39000, loss: 0.55166, acc: 81.2%, valid_acc: 86.6%.
# Minibatch step: 39500, loss: 0.37986, acc: 87.5%, valid_acc: 86.4%.
# Minibatch step: 40000, loss: 0.21230, acc: 93.8%, valid_acc: 86.0%.
# Minibatch step: 40500, loss: 0.71105, acc: 81.2%, valid_acc: 87.2%.
# Minibatch step: 41000, loss: 0.17462, acc: 93.8%, valid_acc: 86.9%.
# Minibatch step: 41500, loss: 0.55852, acc: 75.0%, valid_acc: 86.6%.
# Minibatch step: 42000, loss: 0.28394, acc: 93.8%, valid_acc: 86.1%.
# Minibatch step: 42500, loss: 0.23964, acc: 93.8%, valid_acc: 86.6%.
# Minibatch step: 43000, loss: 0.34218, acc: 93.8%, valid_acc: 86.4%.
# Minibatch step: 43500, loss: 0.35672, acc: 93.8%, valid_acc: 86.4%.
# Minibatch step: 44000, loss: 0.26353, acc: 87.5%, valid_acc: 87.2%.
# Minibatch step: 44500, loss: 0.36010, acc: 87.5%, valid_acc: 86.6%.
# Minibatch step: 45000, loss: 0.60941, acc: 81.2%, valid_acc: 87.3%.
# Minibatch step: 45500, loss: 0.03483, acc: 100.0%, valid_acc: 86.4%.
# Minibatch step: 46000, loss: 0.18120, acc: 93.8%, valid_acc: 84.2%.
# Minibatch step: 46500, loss: 0.24009, acc: 93.8%, valid_acc: 83.6%.
# Minibatch step: 47000, loss: 0.35027, acc: 93.8%, valid_acc: 86.6%.
# Minibatch step: 47500, loss: 0.14659, acc: 93.8%, valid_acc: 86.7%.
# Minibatch step: 48000, loss: 0.17252, acc: 93.8%, valid_acc: 86.6%.
# Minibatch step: 48500, loss: 0.75187, acc: 81.2%, valid_acc: 86.8%.
# Minibatch step: 49000, loss: 0.56303, acc: 87.5%, valid_acc: 86.7%.
# Minibatch step: 49500, loss: 0.34737, acc: 87.5%, valid_acc: 86.4%.
# Minibatch step: 50000, loss: 0.86004, acc: 81.2%, valid_acc: 86.8%.
# Minibatch step: 50500, loss: 0.88774, acc: 81.2%, valid_acc: 86.2%.
# Minibatch step: 51000, loss: 0.25625, acc: 93.8%, valid_acc: 87.0%.
# Minibatch step: 51500, loss: 0.09800, acc: 93.8%, valid_acc: 87.4%.
# Minibatch step: 52000, loss: 0.17291, acc: 93.8%, valid_acc: 87.4%.
# Minibatch step: 52500, loss: 1.04164, acc: 81.2%, valid_acc: 87.0%.
# Minibatch step: 53000, loss: 0.33767, acc: 93.8%, valid_acc: 87.1%.
# Minibatch step: 53500, loss: 0.27142, acc: 93.8%, valid_acc: 87.5%.
# Minibatch step: 54000, loss: 0.30192, acc: 93.8%, valid_acc: 87.6%.
# Minibatch step: 54500, loss: 0.57602, acc: 81.2%, valid_acc: 86.9%.
# Minibatch step: 55000, loss: 0.62599, acc: 75.0%, valid_acc: 87.1%.
# Minibatch step: 55500, loss: 0.60522, acc: 81.2%, valid_acc: 86.7%.
# Minibatch step: 56000, loss: 0.34708, acc: 87.5%, valid_acc: 86.8%.
# Minibatch step: 56500, loss: 0.59026, acc: 81.2%, valid_acc: 86.6%.
# Minibatch step: 57000, loss: 0.14450, acc: 100.0%, valid_acc: 86.9%.
# Minibatch step: 57500, loss: 0.30284, acc: 93.8%, valid_acc: 87.3%.
# Minibatch step: 58000, loss: 0.57220, acc: 87.5%, valid_acc: 87.5%.
# Minibatch step: 58500, loss: 0.07502, acc: 93.8%, valid_acc: 87.5%.
# Minibatch step: 59000, loss: 0.48819, acc: 87.5%, valid_acc: 87.4%.
# Minibatch step: 59500, loss: 0.18547, acc: 93.8%, valid_acc: 87.0%.
# Minibatch step: 60000, loss: 0.30984, acc: 87.5%, valid_acc: 87.1%.
# Minibatch step: 60500, loss: 0.62710, acc: 81.2%, valid_acc: 86.8%.
# Minibatch step: 61000, loss: 0.51547, acc: 87.5%, valid_acc: 86.8%.
# Minibatch step: 61500, loss: 0.41444, acc: 87.5%, valid_acc: 87.2%.
# Minibatch step: 62000, loss: 0.56213, acc: 75.0%, valid_acc: 87.1%.
# Minibatch step: 62500, loss: 0.19443, acc: 93.8%, valid_acc: 87.0%.
# Minibatch step: 63000, loss: 0.65047, acc: 75.0%, valid_acc: 87.2%.
# Minibatch step: 63500, loss: 0.23113, acc: 87.5%, valid_acc: 87.4%.
# Minibatch step: 64000, loss: 0.63255, acc: 81.2%, valid_acc: 87.2%.
# Minibatch step: 64500, loss: 1.08483, acc: 75.0%, valid_acc: 86.9%.
# Minibatch step: 65000, loss: 0.35190, acc: 87.5%, valid_acc: 87.6%.
# Minibatch step: 65500, loss: 0.28512, acc: 87.5%, valid_acc: 87.5%.
# Minibatch step: 66000, loss: 0.25661, acc: 93.8%, valid_acc: 87.3%.
# Minibatch step: 66500, loss: 0.44769, acc: 87.5%, valid_acc: 87.5%.
# Minibatch step: 67000, loss: 0.83054, acc: 87.5%, valid_acc: 87.3%.
# Minibatch step: 67500, loss: 0.52935, acc: 87.5%, valid_acc: 87.6%.
# Minibatch step: 68000, loss: 0.36702, acc: 93.8%, valid_acc: 87.1%.
# Minibatch step: 68500, loss: 0.22313, acc: 93.8%, valid_acc: 87.4%.
# Minibatch step: 69000, loss: 0.16408, acc: 93.8%, valid_acc: 87.4%.
# Minibatch step: 69500, loss: 0.49805, acc: 81.2%, valid_acc: 87.6%.
# Minibatch step: 70000, loss: 0.61725, acc: 75.0%, valid_acc: 87.3%.
# Minibatch step: 70500, loss: 0.51890, acc: 87.5%, valid_acc: 87.6%.
# Minibatch step: 71000, loss: 0.46223, acc: 81.2%, valid_acc: 86.9%.
# Minibatch step: 71500, loss: 0.91078, acc: 62.5%, valid_acc: 83.9%.
# Minibatch step: 72000, loss: 0.30570, acc: 87.5%, valid_acc: 87.2%.
# Minibatch step: 72500, loss: 0.48998, acc: 81.2%, valid_acc: 87.0%.
# Minibatch step: 73000, loss: 0.52978, acc: 81.2%, valid_acc: 87.3%.
# Minibatch step: 73500, loss: 0.07901, acc: 100.0%, valid_acc: 87.4%.
# Minibatch step: 74000, loss: 0.60677, acc: 81.2%, valid_acc: 87.3%.
# Minibatch step: 74500, loss: 0.28962, acc: 87.5%, valid_acc: 87.3%.
# Minibatch step: 75000, loss: 1.13926, acc: 68.8%, valid_acc: 86.0%.
# Minibatch step: 75500, loss: 0.09361, acc: 100.0%, valid_acc: 87.5%.
# Minibatch step: 76000, loss: 0.46928, acc: 81.2%, valid_acc: 87.7%.
# Minibatch step: 76500, loss: 0.23756, acc: 93.8%, valid_acc: 87.6%.
# Minibatch step: 77000, loss: 0.80069, acc: 81.2%, valid_acc: 86.6%.
# Minibatch step: 77500, loss: 0.42970, acc: 93.8%, valid_acc: 87.0%.
# Minibatch step: 78000, loss: 0.22578, acc: 93.8%, valid_acc: 87.2%.
# Minibatch step: 78500, loss: 0.03282, acc: 100.0%, valid_acc: 87.9%.
# Minibatch step: 79000, loss: 0.29056, acc: 87.5%, valid_acc: 88.1%.
# Minibatch step: 79500, loss: 0.05397, acc: 100.0%, valid_acc: 87.3%.
# Minibatch step: 80000, loss: 0.25859, acc: 87.5%, valid_acc: 87.7%.
# Minibatch step: 80500, loss: 0.74839, acc: 81.2%, valid_acc: 87.1%.
# Minibatch step: 81000, loss: 0.13299, acc: 93.8%, valid_acc: 87.4%.
# Minibatch step: 81500, loss: 0.27998, acc: 87.5%, valid_acc: 87.8%.
# Minibatch step: 82000, loss: 0.38368, acc: 87.5%, valid_acc: 87.9%.
# Minibatch step: 82500, loss: 0.10569, acc: 93.8%, valid_acc: 87.4%.
# Minibatch step: 83000, loss: 0.27266, acc: 87.5%, valid_acc: 83.2%.
# Minibatch step: 83500, loss: 0.16262, acc: 93.8%, valid_acc: 87.7%.
# Minibatch step: 84000, loss: 0.90827, acc: 81.2%, valid_acc: 84.9%.
# Minibatch step: 84500, loss: 0.66513, acc: 87.5%, valid_acc: 87.3%.
# Minibatch step: 85000, loss: 0.21722, acc: 93.8%, valid_acc: 87.3%.
# Minibatch step: 85500, loss: 0.68800, acc: 68.8%, valid_acc: 87.8%.
# Minibatch step: 86000, loss: 0.07528, acc: 100.0%, valid_acc: 87.6%.
# Minibatch step: 86500, loss: 0.45212, acc: 87.5%, valid_acc: 86.9%.
# Minibatch step: 87000, loss: 0.35319, acc: 87.5%, valid_acc: 87.6%.
# Minibatch step: 87500, loss: 0.37572, acc: 87.5%, valid_acc: 87.6%.
# Minibatch step: 88000, loss: 0.15198, acc: 93.8%, valid_acc: 87.5%.
# Minibatch step: 88500, loss: 0.37351, acc: 87.5%, valid_acc: 87.7%.
# Minibatch step: 89000, loss: 0.38172, acc: 87.5%, valid_acc: 87.2%.
# Minibatch step: 89500, loss: 0.25141, acc: 93.8%, valid_acc: 86.9%.
# Minibatch step: 90000, loss: 0.27600, acc: 93.8%, valid_acc: 87.8%.
# Minibatch step: 90500, loss: 0.43214, acc: 81.2%, valid_acc: 87.3%.
# Minibatch step: 91000, loss: 0.45091, acc: 87.5%, valid_acc: 87.9%.
# Minibatch step: 91500, loss: 0.10299, acc: 100.0%, valid_acc: 88.1%.
# Minibatch step: 92000, loss: 0.55004, acc: 81.2%, valid_acc: 87.3%.
# Minibatch step: 92500, loss: 0.05440, acc: 100.0%, valid_acc: 87.9%.
# Minibatch step: 93000, loss: 0.44619, acc: 87.5%, valid_acc: 87.0%.
# Minibatch step: 93500, loss: 0.08864, acc: 100.0%, valid_acc: 87.8%.
# Minibatch step: 94000, loss: 0.51357, acc: 87.5%, valid_acc: 87.7%.
# Minibatch step: 94500, loss: 0.37869, acc: 87.5%, valid_acc: 87.8%.
# Minibatch step: 95000, loss: 0.48427, acc: 93.8%, valid_acc: 87.7%.
# Minibatch step: 95500, loss: 0.21585, acc: 93.8%, valid_acc: 88.4%.
# Minibatch step: 96000, loss: 0.07093, acc: 100.0%, valid_acc: 88.2%.
# Minibatch step: 96500, loss: 0.31202, acc: 87.5%, valid_acc: 87.1%.
# Minibatch step: 97000, loss: 0.07169, acc: 100.0%, valid_acc: 87.6%.
# Minibatch step: 97500, loss: 0.25125, acc: 93.8%, valid_acc: 87.2%.
# Minibatch step: 98000, loss: 0.79205, acc: 68.8%, valid_acc: 87.8%.
# Minibatch step: 98500, loss: 0.08016, acc: 93.8%, valid_acc: 88.0%.
# Minibatch step: 99000, loss: 0.19793, acc: 93.8%, valid_acc: 87.6%.
# Minibatch step: 99500, loss: 0.44659, acc: 87.5%, valid_acc: 87.5%.
# Minibatch step: 100000, loss: 0.66776, acc: 68.8%, valid_acc: 87.7%.
# Test Accuracy: 92.7%

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# x轴是以对数的底的值log(x).
# plt.plot 绘制折线图.
plt.semilogx(step_val, accuracy_val)
plt.grid(True)
plt.title('Test accuracy by Regularization (Logistic)')
plt.show()
